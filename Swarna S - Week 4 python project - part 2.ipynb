# %% [markdown]
# Data Visualization on Honey Production dataset using seaborn
# and matplotlib libraries.

# %% [markdown]
# Domain : Food and Agriculture

# %%
import numpy as np 
import pandas as pd
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1.Import required libraries and read the dataset.

# %%
data=pd.read_csv('honeyproduction.csv')
data
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %%
data.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
data.tail()
# Out:
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 621    VA   4000.0           41   164000.0    23000.0        3.77   618000.0
# 622    WA  62000.0           41  2542000.0  1017000.0        2.38  6050000.0
# 623    WV   6000.0           48   288000.0    95000.0        2.91   838000.0
# 624    WI  60000.0           69  4140000.0  1863000.0        2.05  8487000.0
# 625    WY  50000.0           51  2550000.0   459000.0        1.87  4769000.0
#
#      year
# 621  2012
# 622  2012
# 623  2012
# 624  2012
# 625  2012

# %% [markdown]
# Observation:
#     In this dataset libary import in pandas then display the top 5 and bottom 5 in the dataset.

# %% [markdown]
# 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
data.sample(5)
# Out:
#     state    numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 19     MS   18000.0           86  1548000.0   898000.0        0.58   898000.0
# 43     AL   17000.0           68  1156000.0   185000.0        0.56   647000.0
# 135    GA   55000.0           57  3135000.0   188000.0        0.70  2195000.0
# 173    AL   12000.0           86  1032000.0   103000.0        1.18  1218000.0
# 417    TX  105000.0           82  8610000.0  1550000.0        0.96  8266000.0
#
#      year
# 19   1998
# 43   1999
# 135  2001
# 173  2002
# 417  2007

# %%
data.shape
# Out:
# (626, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %% [markdown]
# Observation:
#     In this dataset import in sample for few data year(1995,2005,2003,2008,2003).
#     Honey production datset import in data shape (626) column (8)
#     There are two integer dtypes ("Yieldpercol","year") and object one dtype is ("state") float is five dtypes ("numcol","totalprod","stocks","priceperlb","prodvalue").

# %% [markdown]
# 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
x=data['year'].value_counts()
x
# Out:
# 2001    44
# 2002    44
# 2003    44
# 1998    43
# 1999    43
# 2000    43
# 2004    41
# 2005    41
# 2006    41
# 2007    41
# 2008    41
# 2009    40
# 2010    40
# 2011    40
# 2012    40
# Name: year, dtype: int64

# %%
x.plot(kind='pie',autopct='%1.1f%%')
plt.title('percentage distribution of the data in each year')
# Out:
# Text(0.5, 1.0, 'percentage distribution of the data in each year')

# %% [markdown]
# Observation:
#         In this dataset i analyse this percentage distribution of the data in each year therefore lowest percentage of year is (2009 ,2010) then above 7.0% (2002,2003).

# %% [markdown]
# 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.displot(data["priceperlb"],kde=True)
plt.title("Distribution of the price per lb")
# Out:
# Text(0.5, 1.0, 'Distribution of the price per lb')

# %% [markdown]
# Observation:
#  The central point of central tendency is a distplot distribution of "Priceperlb" appears to the rightly skewed.
#  The Majority of prices value few within the range widely spread between 0.5 USD to 1.5 USD per pound.
#  There are appears no gaps to unusual pattern in the distribution, slightly smooth and continuous.

# %% [markdown]
# 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and
# write your findings.

# %%
sns.scatterplot(x=data["numcol"], y=data["prodvalue"], data=data)
plt.title("Relationship between number of honey and production value")
plt.show()

# %% [markdown]
# Observation:
#     The Scatterplot between is "numcol" and "production value" is a shows a upward trend is a slightly increase positive. the upward trend is a number colonies also increase value  and number of production value also increase value , therfore scatter plot scale is a positive relationship increased demand in the product.

# %% [markdown]
# 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable
# 'prodvalue' through boxplot, and write your findings.

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x=data['year'],y = data['prodvalue'])
plt.title('Relationship between Year and Productionvalue')
plt.show()

# %% [markdown]
# Observation:
#     The median production value of year in 1 to 3.5 million in USD there variability in production value in a across year.these outliers represent values significant different the typical production value in the across year.range in the outliers in (2011,2012) is a slightly positive in the other year of the production.

# %% [markdown]
# 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years
# using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
sns.pairplot(data, vars= ['numcol', 'yieldpercol', 'totalprod', 'prodvalue'],hue="year")
plt.show()

# %% [markdown]
# Observation:
#     The Scatterplot between 'numcol'to 'totalprod'shows an a strongest positive relation to upward trend. in 2012 is a highest value increase in total production value.
#     The scatterplot relation between 'numcol' to 'prodvalue' shows an a strongest positive relation to upward trend. in 2010 to 2012 is a highest value in the production value and decrease in other year.
#     The scatterplot relation is 'yieldpercol' to 'total prod' shows an a slightly positive and no relation upward trend.in 2000 to 2005 moderate to total production value is increase and 2012 to yieldpercol in unit also increase.
#     The pairplot and histogram in a univariate distribution of the attributes.

# %% [markdown]
# 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol',
# 'total prod', 'stocks', 'price per lb', 'prodvalue'.

# %%
column=['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']
correlation_matrix =data[column].corr()
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm')
plt.title('correlation heatmap')
plt.show()

# %% [markdown]
# Observation:
#    The heatmap distribution is a highest positive correlation value is a 'numcol' to 'totalprod' which is a expected to highest number of colonies produce more honey.strongly positive correlation in a 'total prod' to 'prod value'.the negative correlation is a 'yield percol','stocks''prodvalue'.which makes since increase in production surplus to honey.and also decrease in price.
